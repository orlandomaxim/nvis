# %%
from glob import glob
import rasterio
from rasterio.crs import CRS
import os
import pandas as pd
pd.set_option('display.max_colwidth', None)
import geopandas as gpd
from dicttoxml import dicttoxml
from xml.dom.minidom import parseString
import re

# %%
delivery_name = 'Kangaroo_Island2020'
# delivery_name = 'KangarooIsland_AdditionalScene'
outputs = 'NVIS_8L_fm_mape_r1_KI2020'

# delivery_name = 'KangarooIsland_2025'
# outputs = 'NVIS_8L_fm_mape_r1_KI2025'

# delivery_name = 'Billabong'
# outputs = 'NVIS_8L_fm_mape_r1_Billabong'

# delivery_name = 'MulgaLands'
# outputs = 'NVIS_8L_fm_mape_r1_MulgaLands'

# delivery_name = 'Tenterfield'
# outputs = 'NVIS_8L_fm_mape_r1_Tenterfield'

nn_outputs_path = f'/mnt/datapool1/datapool1/datasets/nvis_outputs/{outputs}/raw'
polygon_path = f'/mnt/datapool1/datapool1/datasets/nvis_outputs/{outputs}/clipping_polygons'
output_path = f'/mnt/datapool1/datapool1/datasets/nvis_outputs/{outputs}/clipped'
merged_path = f'/mnt/datapool1/datapool1/datasets/nvis_outputs/{outputs}/merged'
processing_summary = glob(f'/mnt/datapool2/Archive/EO_IMAGERY/raw/aoi/{delivery_name}/**/01_Raw/processing_summary.csv', recursive=True)[0]

polygons = glob('/mnt/datapool1/datapool1/datasets/nn_datasets/polygons/KI2020/*.geojson')
nn_datasets = glob('/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/**/*.hdf5', recursive=True)

# %%
def get_geospatial_metadata(merged_tif):
    metadata = {}

    with rasterio.open(merged_tif) as src:
        metadata['driver'] = src.driver
        metadata['count'] = src.count
        metadata['width'] = src.width
        metadata['height'] = src.height
        metadata['dtype'] = src.dtypes[0]
        metadata['nodata'] = src.nodata

        metadata['crs'] = src.crs.to_string()

        metadata['bounds'] = {
            'left': src.bounds.left,
            'bottom': src.bounds.bottom,
            'right': src.bounds.right,
            'top': src.bounds.top
        }

        metadata['resolution'] = {
            'x': abs(src.res[0]),
            'y': abs(src.res[1])
        }

        metadata['transform'] = list(src.transform)

        width_meters = (src.bounds.right - src.bounds.left)
        height_meters = (src.bounds.top - src.bounds.bottom)
        metadata['spatial_extent'] = {
            'width_meters': width_meters,
            'height_meters': height_meters,
            'area_square_meters': width_meters * height_meters
        }

        # metadata['bands'] = [
        #     {'band_number': 1, 'height_range': 'below_0.5m', 'min': },
        #     {'band_number': 2, 'height_range': '0.5-1m'},
        #     {'band_number': 3, 'height_range': '1-2m'},
        #     {'band_number': 4, 'height_range': 'above_2m'},
        #     {'band_number': 5, 'height_range': 'below_3m'},
        #     {'band_number': 6, 'height_range': 'below_10m'},
        #     {'band_number': 7, 'height_range': '10-30m'},
        #     {'band_number': 8, 'height_range': 'above_30m'}
        # ]
        metadata['bands'] = []
        for band_num in range(1, src.count + 1):
            band_data = src.read(band_num, masked=True)
            
            # Calculate statistics, ignoring nodata values
            band_info = {
                'band_number': band_num,
                'height_range': {
                    1: 'below_0.5m',
                    2: '0.5-1m', 
                    3: '1-2m',
                    4: 'above_2m',
                    5: 'below_3m',
                    6: 'below_10m',
                    7: '10-30m',
                    8: 'above_30m'
                }.get(band_num, f'band_{band_num}'),
                'min': float(band_data.min()) if not band_data.mask.all() else None,
                'max': float(band_data.max()) if not band_data.mask.all() else None,
                'mean': float(band_data.mean()) if not band_data.mask.all() else None,
                'std': float(band_data.std()) if not band_data.mask.all() else None,
                'dtype': str(band_data.dtype),
                'valid_pixels': int((~band_data.mask).sum()),
                'total_pixels': int(band_data.size)
            }
            metadata['bands'].append(band_info)

        metadata['units'] = 'cover'

        # Additional technical metadata
        metadata['tiled'] = src.is_tiled
        if src.is_tiled:
            metadata['block_size'] = src.block_shapes[0]  # (height, width) of blocks
        
        # Get compression info from profile if available
        try:
            metadata['compression'] = src.compression.name if src.compression else None
        except:
            metadata['compression'] = None
            
        # Tags (additional metadata stored in the file)
        # metadata['tags'] = dict(src.tags())

    return metadata

# %%
print(nn_datasets[0])
print(nn_datasets[0].split('/')[7])
# Out:
# /mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_2_RECORD_Record008_7855_067_chm_blur20_cc8_layer/200130_0127Q6_PH6_LN_dn_s4_i5__LGN_town_ngc5_ch_LC_go2_sb_st_wg_ko_bound_train_test/KangarooIsland_2025_JL1KF02B06_0018_20250210_1380085_COMBINED_Ortho_Merged.hdf5
# train

# %%
def get_polygon_area(file, decimals=6, clip_to=None, dissolve=False):
    """Calculate area of polygons in hectares, optionally clipped to a boundary
    
    Args:
        file (str): Path to vector file or geodataframe
        decimals (int): Number of decimal places to round to
        clip_to (GeoDataFrame, optional): GeoDataFrame to clip geometries to
        
    Returns:
        str: Area in hectares as string
    """
    if isinstance(file, str):
        # Check if file exists
        if not os.path.exists(file):
            raise FileNotFoundError(f"File {file} does not exist.")
        gdf = gpd.read_file(file)
    elif isinstance(file, gpd.GeoDataFrame):
        gdf = file
    else:
        raise ValueError("Input must be a file path or a GeoDataFrame.")
    # gdf['geometry'] = gdf['geometry'].apply(lambda geom: geometrycollection_to_multipolygon(geom))
    if clip_to is not None:
        # Handle clip_to as either string file path or GeoDataFrame
        if isinstance(clip_to, str):
            clip_gdf = gpd.read_file(clip_to)
        else:
            clip_gdf = clip_to

        # Ensure same CRS
        if gdf.crs != clip_gdf.crs:
            clip_gdf = clip_gdf.to_crs(gdf.crs)
        
        # Perform clip
        gdf = gpd.clip(gdf, clip_gdf)

    if dissolve:
        gdf = gdf.dissolve()
    return round(gdf.geometry.area.sum() / 10000, decimals)

def get_train_test_areas(train_test_polygons):
    """
    Get the train and test areas from the train_test_polygons files
    """
    train_test_areas = {'train_area': 0, 'test_area': 0}
    for file in train_test_polygons:
        file_gdf = gpd.read_file(file)
        train_gdf = file_gdf[file_gdf['train'] == 1]
        test_gdf = file_gdf[file_gdf['test'] == 1]
        train_test_areas['train_area'] += get_polygon_area(train_gdf)
        train_test_areas['test_area'] += get_polygon_area(test_gdf)
    print(f"Train area: {train_test_areas['train_area']} ha")
    print(f"Test area: {train_test_areas['test_area']} ha")
    print(f"Train percentage: {train_test_areas['train_area'] / (train_test_areas['train_area'] + train_test_areas['test_area']) * 100:.2f}%")
    print(f"Test percentage: {train_test_areas['test_area'] / (train_test_areas['train_area'] + train_test_areas['test_area']) * 100:.2f}%")
    return train_test_areas

# %%
als_areas = {'NVIS_8L_fm_mape_r1_KI2020':       [{'date': '30/01/2020', 'area': '2536', 'sensor': 'RIEGL Q680i-S'},
                                                 {'date': '07/02/2020', 'area': '2048', 'sensor': 'RIEGL Q680i-S'},
                                                 {'date': '23/02/2020', 'area': '599', 'sensor': 'RIEGL Q680i-S'},
                                                 {'date': '13/04/2020', 'area': '1985', 'sensor': 'RIEGL Q680i-S'},
                                                 {'date': '14/04/2020', 'area': '3782', 'sensor': 'RIEGL Q680i-S'},
                                                 {'date': '10/09/2020', 'area': '166', 'sensor': 'RIEGL Q680i-S'},
                                                 {'date': '12/09/2020', 'area': '2822', 'sensor': 'RIEGL Q680i-S'}],
             'NVIS_8L_fm_mape_r1_KI2025':       [{'date': '18/06/2025', 'area': '20903', 'sensor': 'RIEGL VUX 160-23'}],
             'NVIS_8L_fm_mape_r1_WASouth':      [{'date': '20/04/2024', 'area': '18659', 'sensor': 'RIEGL VUX 160-23'},
                                                 {'date': '21/04/2024', 'area': '5409', 'sensor': 'RIEGL VUX 160-23'}],
             'NVIS_8L_fm_mape_r1_Billabong':    [{'date': '15/04/2024', 'area': '16153', 'sensor': 'RIEGL VUX 160-23'}],
             'NVIS_8L_fm_mape_r1_MulgaLands':   [{'date': '25/04/2023', 'area': '9518', 'sensor': 'RIEGL Q680i-S'}],
             'NVIS_8L_fm_mape_r1_Tenterfield':  [{'date': '22/05/2025', 'area': '21576', 'sensor': 'RIEGL VUX 160-23'},
                                                 {'date': '23/05/2025', 'area': '21770', 'sensor': 'RIEGL VUX 160-23'}]
}

# %%
def get_als_metadata(outputs, polygons):
    # print(len(nn_datasets))
    # print(len(polygons))

    # polygons_names = [os.path.splitext(os.path.basename(x))[0] for x in polygons]
    # # print(polygons_names)
    # filtered_datasets = [x for x in nn_datasets if x.split('/')[9] in polygons_names]
    # # print(len(filtered_datasets))
    # train_datasets = [x for x in filtered_datasets if x.split('/')[7] == 'train']
    # test_datasets = [x for x in filtered_datasets if x.split('/')[7] == 'test']
    # # print(train_datasets)
    # # print(test_datasets)
    # datasets_df = pd.DataFrame({'datasets': filtered_datasets})
    # train_datasets_df = pd.DataFrame({'train_datasets': train_datasets})
    # test_datasets_df = pd.DataFrame({'test_datasets': test_datasets})
    # train_datasets_df['image_tile'] = train_datasets_df['train_datasets'].apply(lambda x: os.path.splitext(os.path.basename(x))[0])
    # test_datasets_df['image_tile'] = test_datasets_df['test_datasets'].apply(lambda x: os.path.splitext(os.path.basename(x))[0])
    # # print(train_datasets_df)
    # # print(test_datasets_df)

    # # print(polygons_names)
    # datasets_df['als_name'] = datasets_df['datasets'].apply(lambda x: x.split('/')[8])
    # datasets_df['als_date'] = datasets_df['als_name'].str.extract(r'^(\d{6})')
    # print(datasets_df['als_date'].unique())

    als_metadata = get_train_test_areas(polygons)
    print(als_metadata)
    als_metadata['captures'] = []
    for als_area in als_areas[outputs]:
        als_metadata['captures'].append(als_area)
        # print(als_area)
    # print(als_areas[outputs])
    return als_metadata

als_metadata_dict = get_als_metadata(outputs, polygons)
print(als_metadata_dict)
# Out:
# Train area: 7498.509053999999 ha
# Test area: 1265.7581250000007 ha
# Train percentage: 85.56%
# Test percentage: 14.44%
# {'train_area': 7498.509053999999, 'test_area': 1265.7581250000007}
# {'train_area': 7498.509053999999, 'test_area': 1265.7581250000007, 'captures': [{'date': '30/01/2020', 'area': '2536', 'sensor': 'RIEGL Q680i-S'}, {'date': '07/02/2020', 'area': '2048', 'sensor': 'RIEGL Q680i-S'}, {'date': '23/02/2020', 'area': '599', 'sensor': 'RIEGL Q680i-S'}, {'date': '13/04/2020', 'area': '1985', 'sensor': 'RIEGL Q680i-S'}, {'date': '14/04/2020', 'area': '3782', 'sensor': 'RIEGL Q680i-S'}, {'date': '10/09/2020', 'area': '166', 'sensor': 'RIEGL Q680i-S'}, {'date': '12/09/2020', 'area': '2822', 'sensor': 'RIEGL Q680i-S'}]}
# /home/tony/miniconda3/envs/qgis_env/lib/python3.9/site-packages/pyogrio/raw.py:198: RuntimeWarning: Several features with id = 1 have been found. Altering it to be unique. This warning will not be emitted anymore for this layer
#   return ogr_read(

# %%
# geospatial_metadata_dict = get_geospatial_metadata('/mnt/BAMspace3/2_project_specific/client_work/NVIS/NVIS_V7_Validation/Final_Deliverables/Eastern_Australia_Mulga_Shrublands/Eastern_Australia_Mulga_Shrublands_ground_cover.tif')
# print(get_geospatial_metadata('/mnt/BAMspace3/2_project_specific/client_work/NVIS/NVIS_V7_Validation/Final_Deliverables/Eastern_Australia_Mulga_Shrublands/Eastern_Australia_Mulga_Shrublands_middle_cover.tif'))
# print(get_geospatial_metadata('/mnt/BAMspace3/2_project_specific/client_work/NVIS/NVIS_V7_Validation/Final_Deliverables/Eastern_Australia_Mulga_Shrublands/Eastern_Australia_Mulga_Shrublands_upper_cover.tif'))

geospatial_metadata_dict = get_geospatial_metadata('/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/merged_clipped/NVIS_8L_fm_mape_r1_KI2020_all_merged_clipped_epsg9473.tif')
print(geospatial_metadata_dict)
# Out:
# {'driver': 'GTiff', 'count': 8, 'width': 11646, 'height': 5950, 'dtype': 'float32', 'nodata': -9999.0, 'crs': 'EPSG:9473', 'bounds': {'left': 408458.0397783468, 'bottom': -3953092.1752102603, 'right': 524870.1557080749, 'top': -3893616.639422704}, 'resolution': {'x': 9.995888367656544, 'y': 9.995888367656544}, 'transform': [9.995888367656544, 0.0, 408458.0397783468, 0.0, -9.995888367656544, -3893616.639422704, 0.0, 0.0, 1.0], 'spatial_extent': {'width_meters': 116412.11592972814, 'height_meters': 59475.53578755632, 'area_square_meters': 6923672967.083701}, 'bands': [{'band_number': 1, 'height_range': 'below_0.5m', 'min': 0.0, 'max': 0.8188452124595642, 'mean': 0.04739305799946643, 'std': 0.06404414008407064, 'dtype': 'float32', 'valid_pixels': 40969170, 'total_pixels': 69293700}, {'band_number': 2, 'height_range': '0.5-1m', 'min': 0.0, 'max': 0.6298410296440125, 'mean': 0.046633203089054526, 'std': 0.04077914826477433, 'dtype': 'float32', 'valid_pixels': 40969170, 'total_pixels': 69293700}, {'band_number': 3, 'height_range': '1-2m', 'min': 0.0, 'max': 0.495736688375473, 'mean': 0.05624582460420848, 'std': 0.04999397584427608, 'dtype': 'float32', 'valid_pixels': 40969170, 'total_pixels': 69293700}, {'band_number': 4, 'height_range': 'above_2m', 'min': 0.0, 'max': 0.9819592833518982, 'mean': 0.15735576288218678, 'std': 0.1676844449912774, 'dtype': 'float32', 'valid_pixels': 40969170, 'total_pixels': 69293700}, {'band_number': 5, 'height_range': 'below_3m', 'min': 0.0, 'max': 0.9012020230293274, 'mean': 0.12658524690639328, 'std': 0.11216709134143049, 'dtype': 'float32', 'valid_pixels': 40969170, 'total_pixels': 69293700}, {'band_number': 6, 'height_range': 'below_10m', 'min': 0.0, 'max': 0.9700438976287842, 'mean': 0.19413473594900751, 'std': 0.17573478644671306, 'dtype': 'float32', 'valid_pixels': 40969170, 'total_pixels': 69293700}, {'band_number': 7, 'height_range': '10-30m', 'min': 0.0, 'max': 0.9586530327796936, 'mean': 0.05994743730468545, 'std': 0.11100636871313647, 'dtype': 'float32', 'valid_pixels': 40969170, 'total_pixels': 69293700}, {'band_number': 8, 'height_range': 'above_30m', 'min': 0.0, 'max': 0.062060337513685226, 'mean': 0.0002735795036929599, 'std': 0.0015873906791766825, 'dtype': 'float32', 'valid_pixels': 40969170, 'total_pixels': 69293700}], 'units': 'cover', 'tiled': True, 'block_size': (256, 256), 'compression': 'zstd'}

# %%
nn_datasets
# Out:
# ['/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_2_Record002_7856_chm_blur20_cc8_layer/250523_A_NSW_2_train_test_split/Tenterfield_JL1KF02B01_0007_20250619_1401662_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_2_Record002_7856_chm_blur20_cc8_layer/250523_A_NSW_2_train_test_split/Tenterfield_JL1KF02B01_0008_20250619_1401662_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Denmark_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Denmark_train_test_split/WA_2025_JL1KF02B04_0012_20241211_1336009_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Denmark_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Denmark_train_test_split/WA_2025_JL1KF02B06_0001_20250220_1336017_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Denmark_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Denmark_train_test_split/WA_2025_JL1KF02B04_0011_20241211_1336012_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Denmark_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Denmark_train_test_split/WA_2025_JL1KF02B04_0011_20241211_1336009_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Denmark_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Denmark_train_test_split/WA_2025_JL1KF02B04_0012_20241211_1336031_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_2_RECORD_Record013_7855_067_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0001_20250512_1380083_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_2_RECORD_Record013_7855_067_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0002_20250512_1380083_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord002_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0002_20250512_1380087_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord002_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0003_20250512_1380087_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord002_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0002_20250512_1380094_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord002_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0003_20250512_1380094_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord018_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0002_20250512_1380092_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord018_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0002_20250512_1380083_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/241009_2401009_BUCKAMBOOL_1_chm_blur20_cc8_layer/buck_train_test_split/24JUL04002838-COMBINED-050258404050_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/241009_2401009_BUCKAMBOOL_1_chm_blur20_cc8_layer/buck_train_test_split/24JUL04002926-COMBINED-050258404050_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record025_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0010_20250619_1401642_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record025_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0010_20250619_1401658_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_EVERDALE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/everdale/24FEB03003513-COMBINED-050211564020_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_EVERDALE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/everdale/24FEB07004143-COMBINED-050211564070_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_BLUE_HILLS_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/bluehill/24JAN21003900-COMBINED-050211187010_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_2_Record001_7856_chm_blur20_cc8_layer/250523_A_NSW_2_train_test_split/Tenterfield_JL1KF02B01_0007_20250619_1401642_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record016_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250701_1401652_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record016_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0010_20250317_1401646_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record016_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250619_1401663_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record016_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250317_1401646_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record016_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0010_20250619_1401663_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record016_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0010_20250317_1401660_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record016_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250317_1401660_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record016_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0012_20250701_1401652_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record026_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0009_20250619_1401658_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_LAKEMERE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/lakemere/24MAR13001910-COMBINED-050236024010_01_P003_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_LAKEMERE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/lakemere/24MAR13001913-COMBINED-050211564090_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_LAKEMERE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/lakemere/23NOV05002009-COMBINED-050211564090_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_LAKEMERE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/lakemere/23SEP29002320-COMBINED-050236024010_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_LAKEMERE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/lakemere/24JAN21003806-COMBINED-050211564040_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_LAKEMERE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/GLEN_train_test_split/23SEP29002320-COMBINED-050236024010_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_LAKEMERE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/GLEN_train_test_split/24MAR13001910-COMBINED-050236024010_01_P003_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_LAKEMERE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/GLEN_train_test_split/24MAR13001913-COMBINED-050211564090_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord020_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0001_20250512_1380087_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord020_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0002_20250512_1380094_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord020_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0001_20250512_1380094_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord020_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0002_20250512_1380087_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record007_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0012_20250619_1401642_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record007_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0013_20250619_1401642_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240411_MORETON_PLAINS_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/lissington_train_test/24APR23002552-COMBINED-050226759030_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240411_MORETON_PLAINS_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/lissington_train_test/24APR23002513-COMBINED-050226759030_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record020_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0007_20250317_1401651_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record020_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0008_20250701_1401654_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record020_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0007_20250317_1401646_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_CONLEA_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/conl_train_test_split/24MAR21003523-COMBINED-050239553010_01_P003_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_CONLEA_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/conl_train_test_split/23NOV20001558-COMBINED-050239553010_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_CONLEA_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/conl_train_test_split/23SEP29002407-COMBINED-050239553010_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_20_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23NOV08023400-COMBINED-050215585070_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_20_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/22NOV21024646-COMBINED-050215585070_01_P003_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_20_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360600_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_20_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23MAY15024321-COMBINED-050215585140_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_20_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360594_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record001_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250317_1401657_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record001_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250317_1401660_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record001_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0012_20250701_1401649_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record001_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0012_20250317_1401657_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/241009_2401009_LOWAN_1_chm_blur20_cc8_layer/lowan_train_test_split/IMG_PNEO3_202309170025537_COMBINED_SEN_PWOI_000289585_1_1_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/241009_2401009_LOWAN_1_chm_blur20_cc8_layer/lowan_train_test_split/IMG_PNEO4_202309040025494_COMBINED_SEN_PWOI_000289585_2_1_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/241009_2401009_LOWAN_1_chm_blur20_cc8_layer/lowan_train_test_split/IMG_PNEO3_202305100026097_COMBINED_SEN_PWOI_000289585_3_2_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240315_NIMBOY_ALS_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240315_Quilpi_to_Burrandilla_line_10_850ft80kn1800khz280lps_bound_train_test_split/IMG_PNEO3_202406240027446_COMBINED_SEN_PWOI_000259370_4_1_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240315_NIMBOY_ALS_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240315_Quilpi_to_Burrandilla_line_10_850ft80kn1800khz280lps_bound_train_test_split/IMG_PNEO4_202404150031547_COMBINED_SEN_PWOI_000259370_3_1_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240315_NIMBOY_ALS_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/nimb_train_test_split/IMG_PNEO4_202404150031547_COMBINED_SEN_PWOI_000259370_3_1_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240315_NIMBOY_ALS_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/nimb_train_test_split/IMG_PNEO3_202401250024282_COMBINED_SEN_PWOI_000259370_1_1_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240315_NIMBOY_ALS_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/nimb_train_test_split/IMG_PNEO4_202404150031552_COMBINED_SEN_PWOI_000259370_2_1_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240315_NIMBOY_ALS_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/nimb_train_test_split/IMG_PNEO3_202406240027446_COMBINED_SEN_PWOI_000259370_4_1_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240315_NIMBOY_ALS_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240315_Quilpi_to_Burrandilla_line_11_850ft80kn1800khz280lps_bound_train_test_split/IMG_PNEO3_202401250024282_COMBINED_SEN_PWOI_000259370_1_1_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240315_NIMBOY_ALS_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240315_Quilpi_to_Burrandilla_line_11_850ft80kn1800khz280lps_bound_train_test_split/IMG_PNEO4_202404150031552_COMBINED_SEN_PWOI_000259370_2_1_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_2_Record004_7856_chm_blur20_cc8_layer/250523_A_NSW_2_train_test_split/Tenterfield_JL1KF02B01_0009_20250619_1401655_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_2_Record004_7856_chm_blur20_cc8_layer/250523_A_NSW_2_train_test_split/Tenterfield_JL1KF02B01_0009_20250619_1401662_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/241010_RoseIsle_East_1_chm_blur20_cc8_layer/rose_train_test_split/24OCT01002521-COMBINED-050258404030_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/241010_RoseIsle_East_1_chm_blur20_cc8_layer/rose_train_test_split/24OCT01002503-COMBINED-050258404030_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_2_RECORD_Record002_7855_067_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0001_20250512_1380083_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_2_RECORD_Record002_7855_067_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0001_20250512_1380092_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/230425_Brindingabba_east_1_2_3_4__LGN_nature_ngc5_ch_LC_go1_chm_blur20_cc8_layer/Brindingabba_East_train_test/MulgaLands_JL1KF01C_0007_20230103_1380071_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/230425_Brindingabba_east_1_2_3_4__LGN_nature_ngc5_ch_LC_go1_chm_blur20_cc8_layer/Brindingabba_East_train_test/MulgaLands_JL1KF01C_0006_20230103_1380071_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240411_INVERNESS_CULGOA_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/lissington_train_test/24APR23002431-COMBINED-050226759010_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240411_INVERNESS_CULGOA_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/lissington_train_test/24APR23002517-COMBINED-016377983010_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0014_20250206_1360594_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23MAY15024321-COMBINED-050215585140_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360600_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0014_20250206_1360600_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23NOV08023400-COMBINED-050215585070_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/22NOV21024646-COMBINED-050215585070_01_P003_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record010_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0012_20250619_1401650_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record010_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF01B_0008_20250508_1401659_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record010_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250619_1401650_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record018_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0007_20250317_1401651_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record018_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0007_20250317_1401646_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record018_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0008_20250701_1401654_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_6_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23DEC17024223-COMBINED-050215585010_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_6_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360593_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_6_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23APR06023303-COMBINED-050215585080_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_6_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23FEB13024205-COMBINED-050215585150_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_6_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360597_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record023_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250619_1401658_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_3_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF02B04_0011_20241211_1336028_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_3_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF02B06_0001_20250220_1336018_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_3_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF02B05_0026_20250130_1336004_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_3_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF01C_0004_20250224_1336016_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_3_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF02B06_0001_20250220_1336002_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_3_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF01C_0003_20250224_1336016_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_3_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF01C_0005_20250224_1336016_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord004_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0003_20250512_1380092_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record012_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0006_20250317_1401661_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record012_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0007_20250317_1401661_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record012_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B04_0003_20250507_1401656_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record012_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF01B_0002_20250508_1401659_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record031_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0006_20250317_1401661_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF02B06_0001_20250220_1336017_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF01C_0004_20250224_1336010_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF01C_0005_20250224_1336010_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF02B04_0012_20241211_1336009_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF02B06_0001_20250220_1336018_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF02B06_0002_20250220_1336017_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF01C_0034_20230715_200175769_COMBINED_Ortho_1_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_2_Record007_7856_chm_blur20_cc8_layer/250523_A_NSW_2_train_test_split/Tenterfield_JL1KF02B01_0010_20250619_1401655_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_2_Record007_7856_chm_blur20_cc8_layer/250523_A_NSW_2_train_test_split/Tenterfield_JL1KF02B01_0010_20250619_1401642_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/200912_0910Q6_TR06_chm_blur20_cc8_layer/200912_0910Q6_TR06_bound_train_test/Kangaroo_Island2020_JL1KF01A_0034_20201211_1325657_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/200912_0910Q6_TR06_chm_blur20_cc8_layer/200912_0910Q6_TR06_bound_train_test/Kangaroo_Island2020_JL1GF02A_0007_20201126_1325396_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/200912_0910Q6_TR06_chm_blur20_cc8_layer/200912_0910Q6_TR06_bound_train_test/Kangaroo_Island2020_JL1GF02A_0006_20201126_1325396_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record028_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0009_20250317_1401661_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record028_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B06_0041_20250525_1401648_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record028_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B04_0006_20250507_1401656_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record014_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B04_0004_20250507_1401656_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record014_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0008_20250619_1401658_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record014_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B04_0005_20250507_1401656_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record024_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250619_1401658_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord019_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0002_20250512_1380087_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord019_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0002_20250512_1380092_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/200910_YF_2020-09-10_chm_blur20_cc8_layer/200910_YF_2020-09-10_bound_train_test/Kangaroo_Island2020_JL1GF02A_0007_20201126_1325396_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/200910_YF_2020-09-10_chm_blur20_cc8_layer/200910_YF_2020-09-10_bound_train_test/Kangaroo_Island2020_JL1GF02A_0006_20201126_1325396_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/230425_Dungarvan_ALS_1-9__LGN_nature_ngc5_ch_LC_go1_chm_blur20_cc8_layer/Dungarvan_train_test/MulgaLands_JL1KF01C_0011_20230103_1380077_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/230425_Dungarvan_ALS_1-9__LGN_nature_ngc5_ch_LC_go1_chm_blur20_cc8_layer/Dungarvan_train_test/MulgaLands_JL1KF01C_0012_20230103_1380079_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/230425_Dungarvan_ALS_1-9__LGN_nature_ngc5_ch_LC_go1_chm_blur20_cc8_layer/Dungarvan_train_test/MulgaLands_JL1KF01C_0011_20230103_1380079_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/230425_Dungarvan_ALS_1-9__LGN_nature_ngc5_ch_LC_go1_chm_blur20_cc8_layer/Dungarvan_train_test/MulgaLands_JL1KF01C_0012_20230103_1380077_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord003_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0003_20250512_1380092_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_1_7855_067_RECORDRecord003_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0003_20250512_1380087_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/200912_0910Q6_TR10_chm_blur20_cc8_layer/200912_0910Q6_TR10_bound_train_test/Kangaroo_Island2020_JL1KF01A_0034_20201211_1325657_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/200912_0910Q6_TR01_chm_blur20_cc8_layer/200912_0910Q6_TR01_bound_train_test/Kangaroo_Island2020_JL1GF02B_0010_20201108_1325560_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/200912_0910Q6_TR01_chm_blur20_cc8_layer/200912_0910Q6_TR01_bound_train_test/Kangaroo_Island2020_JL1GF02B_0009_20201108_1325560_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record006_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0013_20250619_1401642_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record027_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0008_20250619_1401642_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record027_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0008_20250619_1401655_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_2_RECORD_Record014_7855_067_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0001_20250512_1380083_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_2_RECORD_Record014_7855_067_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0001_20250512_1380092_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_2_RECORD_Record014_7855_067_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0002_20250512_1380083_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_19_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360594_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_19_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23MAY15024321-COMBINED-050215585140_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_19_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23APR23024619-COMBINED-050215585140_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_19_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/22NOV21024646-COMBINED-050215585070_01_P003_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_19_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360592_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_19_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23NOV08023400-COMBINED-050215585070_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_19_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B02_0009_20250208_1360596_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record017_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250619_1401663_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record017_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0010_20250317_1401646_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record017_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250701_1401652_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record017_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0010_20250619_1401663_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record017_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250317_1401646_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record017_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250701_1401654_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record021_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0008_20250317_1401651_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record021_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0008_20250317_1401661_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/200912_0910Q6_TR03ab_chm_blur20_cc8_layer/200912_0910Q6_TR03ab_bound_train_test/Kangaroo_Island2020_JL1KF01A_0035_20201211_1325279_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/200912_0910Q6_TR03ab_chm_blur20_cc8_layer/200912_0910Q6_TR03ab_bound_train_test/Kangaroo_Island2020_JL1KF01A_0034_20201211_1325657_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/200912_0910Q6_TR03ab_chm_blur20_cc8_layer/200912_0910Q6_TR03ab_bound_train_test/Kangaroo_Island2020_JL1GF02A_0006_20201126_1325396_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240325_MYROOLIA_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/gtring_full/23NOV05002003-COMBINED-050211564120_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240325_MYROOLIA_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/gtring_full/23NOV30003059-COMBINED-050232158020_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240325_MYROOLIA_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/MYRO_train_test_split/23NOV30003059-COMBINED-050232158020_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240325_MYROOLIA_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/MYRO_train_test_split/23NOV05002000-COMBINED-050232158030_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240325_MYROOLIA_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/MYRO_train_test_split/24JUN01001937-COMBINED-050232158010_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240325_MYROOLIA_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/MYRO_train_test_split/23NOV05002003-COMBINED-050233523010_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240411_Calindary_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/cali2/23DEC03003817-COMBINED-050216468020_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240411_Calindary_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/cali2/24APR07003018-COMBINED-050216468010_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240411_Calindary_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/cali2/23OCT31004939-COMBINED-050216468020_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240411_Calindary_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/cali2/24APR07003121-COMBINED-050216468010_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record011_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250619_1401650_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record011_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250619_1401658_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record011_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF01B_0008_20250508_1401659_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/241010_Curranyalpa_1_chm_blur20_cc8_layer/curr_train_test_split/AOI2_Redeliver_JL1KF01C_20250112_COMBINED_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/241010_Curranyalpa_1_chm_blur20_cc8_layer/curr_train_test_split/AOI2_Redeliver_JL1KF01C_20250118_COMBINED_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record019_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0007_20250317_1401646_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record019_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0008_20250701_1401654_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record019_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0006_20250317_1401646_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record019_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0007_20250701_1401654_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250618_K_ISLAND_2_RECORD_Record003_7855_067_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0001_20250512_1380083_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_27_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0014_20250206_1360589_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_27_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23MAY15024321-COMBINED-050215585140_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_27_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0014_20250206_1360600_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_27_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23JUL22023202-COMBINED-050215585070_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_27_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/22NOV21024646-COMBINED-050215585070_01_P003_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_27_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23NOV08023400-COMBINED-050215585070_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record029_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B05_0003_20250428_1401647_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record029_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0009_20250317_1401661_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250522_A_NSW_1_7856_Record029_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0009_20250317_1401651_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/200912_0910Q6_TR07_chm_blur20_cc8_layer/200912_0910Q6_TR07_bound_train_test/Kangaroo_Island2020_JL1KF01A_0034_20201211_1325657_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/200912_0910Q6_TR07_chm_blur20_cc8_layer/200912_0910Q6_TR07_bound_train_test/Kangaroo_Island2020_JL1GF02A_0006_20201126_1325396_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record013_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B04_0004_20250507_1401656_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/250523_A_NSW_1_Tenterfield_Record013_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0007_20250317_1401661_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240421_AlbtoEsp_2_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240421_AlbtoEsp_train_test_split/WA_2025_JL1KF01C_0055_20250328_1336001_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240421_AlbtoEsp_2_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240421_AlbtoEsp_train_test_split/WA_2025_JL1KF02B05_0036_20250131_1336006_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240421_AlbtoEsp_2_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240421_AlbtoEsp_train_test_split/WA_2025_JL1KF01C_0054_20250328_1336001_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240421_AlbtoEsp_2_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240421_AlbtoEsp_train_test_split/WA_2025_JL1KF01C_0054_20250328_1336011_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240421_AlbtoEsp_2_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240421_AlbtoEsp_train_test_split/WA_2025_JL1KF02B05_0035_20250131_1336006_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_7_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23APR06023303-COMBINED-050215585080_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_7_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360597_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_7_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23FEB13024205-COMBINED-050215585150_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240415_TALISKER_7_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360593_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_GLENORA_KINGS_BORE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/GLEN_train_test_split/24MAR13001913-COMBINED-050211564090_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_GLENORA_KINGS_BORE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/GLEN_train_test_split/24MAR13001910-COMBINED-050236024010_01_P003_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_GLENORA_KINGS_BORE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/GLEN_train_test_split/23SEP29002320-COMBINED-050236024010_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_GLENORA_KINGS_BORE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/GLEN_train_test_split/24MAR13001959-COMBINED-050236024010_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_GLENORA_KINGS_BORE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/lakemere/24MAR13001913-COMBINED-050211564090_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/train/240326_GLENORA_KINGS_BORE_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/lakemere/24MAR13001910-COMBINED-050236024010_01_P003_ortho.hdf5',
# ...
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record014_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0012_20250701_1401654_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record014_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B02_0014_20250523_1401645_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record014_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250701_1401654_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250618_K_ISLAND_2_RECORD_Record002_7855_067_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0001_20250512_1380092_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250618_K_ISLAND_2_RECORD_Record002_7855_067_chm_blur20_cc8_layer/KI_2025_train_test_split/KangarooIsland_2025_JL1KF02B04_0001_20250512_1380083_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250523_A_NSW_1_Tenterfield_Record024_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B04_0006_20250507_1401656_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250523_A_NSW_1_Tenterfield_Record024_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF01B_0005_20250508_1401659_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250523_A_NSW_1_Tenterfield_Record024_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0009_20250619_1401658_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250523_A_NSW_1_Tenterfield_Record024_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF01B_0005_20250508_1401659_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250523_A_NSW_1_Tenterfield_Record024_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B04_0006_20250507_1401656_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/200912_0910Q6_TR03ab_chm_blur20_cc8_layer/200912_0910Q6_TR03ab_bound_train_test/Kangaroo_Island2020_JL1GF02A_0006_20201126_1325396_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/200912_0910Q6_TR03ab_chm_blur20_cc8_layer/200912_0910Q6_TR03ab_bound_train_test/Kangaroo_Island2020_JL1KF01A_0035_20201211_1325279_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/200912_0910Q6_TR03ab_chm_blur20_cc8_layer/200912_0910Q6_TR03ab_bound_train_test/Kangaroo_Island2020_JL1KF01A_0034_20201211_1325657_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250523_A_NSW_2_Record003_7856_chm_blur20_cc8_layer/250523_A_NSW_2_train_test_split/Tenterfield_JL1KF02B01_0008_20250619_1401662_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/230425_Fords_Bridge_ALS_1_2_3_4__LGN_nature_ngc5_ch_LC_go1_chm_blur20_cc8_layer/Fords_Bridge_train_test/MulgaLands_JL1KF01B_0043_20230511_1380074_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/230425_Fords_Bridge_ALS_1_2_3_4__LGN_nature_ngc5_ch_LC_go1_chm_blur20_cc8_layer/Fords_Bridge_train_test/MulgaLands_JL1KF01B_0042_20230511_1380074_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240420_Denmark_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Denmark_train_test_split/WA_2025_JL1KF02B04_0011_20241211_1336009_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240420_Denmark_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Denmark_train_test_split/WA_2025_JL1KF02B04_0012_20241211_1336031_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240420_Denmark_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Denmark_train_test_split/WA_2025_JL1KF02B06_0001_20250220_1336017_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240420_Denmark_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Denmark_train_test_split/WA_2025_JL1KF02B04_0011_20241211_1336012_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240420_Denmark_1_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Denmark_train_test_split/WA_2025_JL1KF02B04_0012_20241211_1336009_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record005_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0013_20250619_1401658_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record005_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0013_20250619_1401650_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250523_A_NSW_1_Tenterfield_Record022_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0009_20250317_1401661_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250523_A_NSW_1_Tenterfield_Record022_500ft80kn2400khz400lps_chm_blur20_cc8_layer/250523_A_NSW_1_train_test_split/Tenterfield_JL1KF02B05_0003_20250428_1401647_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF01C_0034_20230715_200175769_COMBINED_Ortho_1_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF02B06_0001_20250220_1336018_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF01C_0005_20250224_1336010_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF02B06_0002_20250220_1336017_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF01C_0004_20250224_1336010_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF02B06_0001_20250220_1336017_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240420_Walpole_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/240420_Walpole_train_test_split/WA_2025_JL1KF02B04_0012_20241211_1336009_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record003_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B02_0015_20250523_1401645_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record003_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0013_20250701_1401654_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0014_20250206_1360589_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23DEC17024223-COMBINED-050215585010_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360597_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360589_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23APR09023945-COMBINED-050215585150_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0014_20250206_1360597_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_5_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23FEB13024205-COMBINED-050215585150_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250523_A_NSW_2_Record006_7856_chm_blur20_cc8_layer/250523_A_NSW_2_train_test_split/Tenterfield_JL1KF02B01_0009_20250619_1401642_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250523_A_NSW_2_Record006_7856_chm_blur20_cc8_layer/250523_A_NSW_2_train_test_split/Tenterfield_JL1KF02B01_0010_20250619_1401642_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record019_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B02_0013_20250523_1401645_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record019_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF01B_0007_20250508_1401643_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record019_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250701_1401654_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record019_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0010_20250317_1401651_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/22NOV21024646-COMBINED-050215585070_01_P003_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0014_20250206_1360594_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0014_20250206_1360589_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360600_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23NOV08023400-COMBINED-050215585070_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360589_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0014_20250206_1360600_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23MAY15024321-COMBINED-050215585140_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_26_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23APR09023945-COMBINED-050215585150_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/241009_LOWAN_1_chm_blur20_cc8_layer/lowan_train_test_split/IMG_PNEO4_202309040025494_COMBINED_SEN_PWOI_000289585_2_1_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/241009_LOWAN_1_chm_blur20_cc8_layer/lowan_train_test_split/IMG_PNEO3_202309170025537_COMBINED_SEN_PWOI_000289585_1_1_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/241009_LOWAN_1_chm_blur20_cc8_layer/lowan_train_test_split/IMG_PNEO3_202305100026097_COMBINED_SEN_PWOI_000289585_3_2_F_1_COMBINED_R1C1_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_3_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23APR09023945-COMBINED-050215585150_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_3_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23DEC17024223-COMBINED-050215585010_01_P001_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_3_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/Billabong_JL1KF02B04_0013_20250206_1360589_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/240415_TALISKER_3_850ft80kn1800khz280lps_chm_blur20_cc8_layer/billabong_train_test_split/23APR09024410-COMBINED-050215585010_01_P002_ortho.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record012_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250619_1401644_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record012_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250619_1401650_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record012_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF01B_0008_20250508_1401659_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record012_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0011_20250317_1401661_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record012_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF01B_0007_20250508_1401659_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250522_A_NSW_1_7856_Record008_chm_blur20_cc8_layer/250522_A_NSW_1_train_test_split/Tenterfield_JL1KF02B01_0012_20250619_1401642_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/241010_Curranyalpa_1_chm_blur20_cc8_layer/curr_train_test_split/AOI2_Redeliver_JL1KF01C_20250118_COMBINED_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/241010_Curranyalpa_1_chm_blur20_cc8_layer/curr_train_test_split/AOI2_Redeliver_JL1KF01C_20250112_COMBINED_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/250523_A_NSW_2_Record005_7856_chm_blur20_cc8_layer/250523_A_NSW_2_train_test_split/Tenterfield_JL1KF02B01_0009_20250619_1401655_COMBINED_Ortho_Merged.hdf5',
#  '/mnt/datapool1/datapool1/datasets/nn_datasets/NVIS/test/241009_2401009_BUCKAMBOOL_1_chm_blur20_cc8_layer/buck_train_test_split/24JUL04002838-COMBINED-050258404050_01_P002_ortho.hdf5',
#  ...]

# %%
clipping_polygons = glob(polygon_path + '/*.geojson')
print(clipping_polygons)
clipping_polygon_names = [os.path.splitext(os.path.basename(f))[0].replace(f'{delivery_name}_', '').replace('KangarooIsland_AdditionalScene_', '') for f in clipping_polygons]
print(clipping_polygon_names)
imagery_metadata_dict = {}
imagery_metadata_dict['mosaic_tiles'] = clipping_polygon_names
print(imagery_metadata_dict)
# Out:
# ['/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1KF01A_0031_20201226_1325274_MSS_Ortho.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1KF01A_0032_20201226_1325275_MSS_Ortho.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/KangarooIsland_AdditionalScene_JL1KF01A_0032_20201226_200036508_MSS_Ortho.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1KF01A_0031_20201226_1325656_MSS_Ortho_2.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1KF01A_0007_20220109_1325278_MSS_Ortho.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1GF02A_0005_20201220_1325480_MSS_Ortho_1.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1KF01A_0030_20201226_1325656_MSS_Ortho.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1KF01A_0031_20201226_1325656_MSS_Ortho_3.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1GF02A_0005_20201220_1325480_MSS_Ortho.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1KF01A_0032_20201226_1325274_MSS_Ortho.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1KF01A_0033_20201226_1325656_MSS_Ortho.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1GF02B_0011_20201108_1325560_MSS_Ortho.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1KF01A_0031_20201226_1325656_MSS_Ortho.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1KF01A_0031_20201226_1325656_MSS_Ortho_1.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1GF02B_0009_20201108_1325560_MSS_Ortho.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1KF01A_0030_20201226_1325280_MSS_Ortho.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1KF01A_0032_20201226_1325656_MSS_Ortho.geojson', '/mnt/datapool1/datapool1/datasets/nvis_outputs/NVIS_8L_fm_mape_r1_KI2020/clipping_polygons/Kangaroo_Island2020_JL1KF01A_0033_20201226_1325274_MSS_Ortho.geojson']
# ['JL1KF01A_0031_20201226_1325274_MSS_Ortho', 'JL1KF01A_0032_20201226_1325275_MSS_Ortho', 'JL1KF01A_0032_20201226_200036508_MSS_Ortho', 'JL1KF01A_0031_20201226_1325656_MSS_Ortho_2', 'JL1KF01A_0007_20220109_1325278_MSS_Ortho', 'JL1GF02A_0005_20201220_1325480_MSS_Ortho_1', 'JL1KF01A_0030_20201226_1325656_MSS_Ortho', 'JL1KF01A_0031_20201226_1325656_MSS_Ortho_3', 'JL1GF02A_0005_20201220_1325480_MSS_Ortho', 'JL1KF01A_0032_20201226_1325274_MSS_Ortho', 'JL1KF01A_0033_20201226_1325656_MSS_Ortho', 'JL1GF02B_0011_20201108_1325560_MSS_Ortho', 'JL1KF01A_0031_20201226_1325656_MSS_Ortho', 'JL1KF01A_0031_20201226_1325656_MSS_Ortho_1', 'JL1GF02B_0009_20201108_1325560_MSS_Ortho', 'JL1KF01A_0030_20201226_1325280_MSS_Ortho', 'JL1KF01A_0032_20201226_1325656_MSS_Ortho', 'JL1KF01A_0033_20201226_1325274_MSS_Ortho']
# {'mosaic_tiles': ['JL1KF01A_0031_20201226_1325274_MSS_Ortho', 'JL1KF01A_0032_20201226_1325275_MSS_Ortho', 'JL1KF01A_0032_20201226_200036508_MSS_Ortho', 'JL1KF01A_0031_20201226_1325656_MSS_Ortho_2', 'JL1KF01A_0007_20220109_1325278_MSS_Ortho', 'JL1GF02A_0005_20201220_1325480_MSS_Ortho_1', 'JL1KF01A_0030_20201226_1325656_MSS_Ortho', 'JL1KF01A_0031_20201226_1325656_MSS_Ortho_3', 'JL1GF02A_0005_20201220_1325480_MSS_Ortho', 'JL1KF01A_0032_20201226_1325274_MSS_Ortho', 'JL1KF01A_0033_20201226_1325656_MSS_Ortho', 'JL1GF02B_0011_20201108_1325560_MSS_Ortho', 'JL1KF01A_0031_20201226_1325656_MSS_Ortho', 'JL1KF01A_0031_20201226_1325656_MSS_Ortho_1', 'JL1GF02B_0009_20201108_1325560_MSS_Ortho', 'JL1KF01A_0030_20201226_1325280_MSS_Ortho', 'JL1KF01A_0032_20201226_1325656_MSS_Ortho', 'JL1KF01A_0033_20201226_1325274_MSS_Ortho']}

# %%
# metadata_dict.to_json('/mnt/datapool1/datapool1/datasets/nvis_outputs/{outputs}/metadata.json')
metadata_dict = {
    'geospatial_metadata': geospatial_metadata_dict,
    'als_metadata': als_metadata_dict,
    'imagery_metadata': imagery_metadata_dict
}
xml_bytes = dicttoxml(metadata_dict, custom_root='MetaData', attr_type=False)
print(xml_bytes)
xml_string = parseString(xml_bytes).toprettyxml()
print(xml_string)
with open(f'/mnt/datapool1/datapool1/datasets/nvis_outputs/{outputs}/KI2020_metadata.xml', 'w') as f:
    f.write(xml_string)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" ?><MetaData><geospatial_metadata><driver>GTiff</driver><count>8</count><width>11646</width><height>5950</height><dtype>float32</dtype><nodata>-9999.0</nodata><crs>EPSG:9473</crs><bounds><left>408458.0397783468</left><bottom>-3953092.1752102603</bottom><right>524870.1557080749</right><top>-3893616.639422704</top></bounds><resolution><x>9.995888367656544</x><y>9.995888367656544</y></resolution><transform><item>9.995888367656544</item><item>0.0</item><item>408458.0397783468</item><item>0.0</item><item>-9.995888367656544</item><item>-3893616.639422704</item><item>0.0</item><item>0.0</item><item>1.0</item></transform><spatial_extent><width_meters>116412.11592972814</width_meters><height_meters>59475.53578755632</height_meters><area_square_meters>6923672967.083701</area_square_meters></spatial_extent><bands><item><band_number>1</band_number><height_range>below_0.5m</height_range><min>0.0</min><max>0.8188452124595642</max><mean>0.04739305799946643</mean><std>0.06404414008407064</std><dtype>float32</dtype><valid_pixels>40969170</valid_pixels><total_pixels>69293700</total_pixels></item><item><band_number>2</band_number><height_range>0.5-1m</height_range><min>0.0</min><max>0.6298410296440125</max><mean>0.046633203089054526</mean><std>0.04077914826477433</std><dtype>float32</dtype><valid_pixels>40969170</valid_pixels><total_pixels>69293700</total_pixels></item><item><band_number>3</band_number><height_range>1-2m</height_range><min>0.0</min><max>0.495736688375473</max><mean>0.05624582460420848</mean><std>0.04999397584427608</std><dtype>float32</dtype><valid_pixels>40969170</valid_pixels><total_pixels>69293700</total_pixels></item><item><band_number>4</band_number><height_range>above_2m</height_range><min>0.0</min><max>0.9819592833518982</max><mean>0.15735576288218678</mean><std>0.1676844449912774</std><dtype>float32</dtype><valid_pixels>40969170</valid_pixels><total_pixels>69293700</total_pixels></item><item><band_number>5</band_number><height_range>below_3m</height_range><min>0.0</min><max>0.9012020230293274</max><mean>0.12658524690639328</mean><std>0.11216709134143049</std><dtype>float32</dtype><valid_pixels>40969170</valid_pixels><total_pixels>69293700</total_pixels></item><item><band_number>6</band_number><height_range>below_10m</height_range><min>0.0</min><max>0.9700438976287842</max><mean>0.19413473594900751</mean><std>0.17573478644671306</std><dtype>float32</dtype><valid_pixels>40969170</valid_pixels><total_pixels>69293700</total_pixels></item><item><band_number>7</band_number><height_range>10-30m</height_range><min>0.0</min><max>0.9586530327796936</max><mean>0.05994743730468545</mean><std>0.11100636871313647</std><dtype>float32</dtype><valid_pixels>40969170</valid_pixels><total_pixels>69293700</total_pixels></item><item><band_number>8</band_number><height_range>above_30m</height_range><min>0.0</min><max>0.062060337513685226</max><mean>0.0002735795036929599</mean><std>0.0015873906791766825</std><dtype>float32</dtype><valid_pixels>40969170</valid_pixels><total_pixels>69293700</total_pixels></item></bands><units>cover</units><tiled>true</tiled><block_size><item>256</item><item>256</item></block_size><compression>zstd</compression></geospatial_metadata><als_metadata><train_area>7498.509053999999</train_area><test_area>1265.7581250000007</test_area><captures><item><date>30/01/2020</date><area>2536</area><sensor>RIEGL Q680i-S</sensor></item><item><date>07/02/2020</date><area>2048</area><sensor>RIEGL Q680i-S</sensor></item><item><date>23/02/2020</date><area>599</area><sensor>RIEGL Q680i-S</sensor></item><item><date>13/04/2020</date><area>1985</area><sensor>RIEGL Q680i-S</sensor></item><item><date>14/04/2020</date><area>3782</area><sensor>RIEGL Q680i-S</sensor></item><item><date>10/09/2020</date><area>166</area><sensor>RIEGL Q680i-S</sensor></item><item><date>12/09/2020</date><area>2822</area><sensor>RIEGL Q680i-S</sensor></item></captures></als_metadata><imagery_metadata><mosaic_tiles><item>JL1KF01A ...
# <?xml version="1.0" ?>
# <MetaData>
# 	<geospatial_metadata>
# 		<driver>GTiff</driver>
# 		<count>8</count>
# 		<width>11646</width>
# 		<height>5950</height>
# 		<dtype>float32</dtype>
# 		<nodata>-9999.0</nodata>
# 		<crs>EPSG:9473</crs>
# 		<bounds>
# 			<left>408458.0397783468</left>
# 			<bottom>-3953092.1752102603</bottom>
# 			<right>524870.1557080749</right>
# 			<top>-3893616.639422704</top>
# 		</bounds>
# 		<resolution>
# 			<x>9.995888367656544</x>
# 			<y>9.995888367656544</y>
# 		</resolution>
# 		<transform>
# 			<item>9.995888367656544</item>
# 			<item>0.0</item>
# 			<item>408458.0397783468</item>
# 			<item>0.0</item>
# 			<item>-9.995888367656544</item>
# 			<item>-3893616.639422704</item>
# 			<item>0.0</item>
# 			<item>0.0</item>
# 			<item>1.0</item>
# 		</transform>
# 		<spatial_extent>
# 			<width_meters>116412.11592972814</width_meters>
# 			<height_meters>59475.53578755632</height_meters>
# 			<area_square_meters>6923672967.083701</area_square_meters>
# 		</spatial_extent>
# 		<bands>
# 			<item>
# 				<band_number>1</band_number>
# 				<height_range>below_0.5m</height_range>
# 				<min>0.0</min>
# 				<max>0.8188452124595642</max>
# 				<mean>0.04739305799946643</mean>
# 				<std>0.06404414008407064</std>
# 				<dtype>float32</dtype>
# 				<valid_pixels>40969170</valid_pixels>
# 				<total_pixels>69293700</total_pixels>
# 			</item>
# 			<item>
# 				<band_number>2</band_number>
# 				<height_range>0.5-1m</height_range>
# 				<min>0.0</min>
# 				<max>0.6298410296440125</max>
# 				<mean>0.046633203089054526</mean>
# 				<std>0.04077914826477433</std>
# 				<dtype>float32</dtype>
# 				<valid_pixels>40969170</valid_pixels>
# 				<total_pixels>69293700</total_pixels>
# 			</item>
# 			<item>
# 				<band_number>3</band_number>
# 				<height_range>1-2m</height_range>
# 				<min>0.0</min>
# 				<max>0.495736688375473</max>
# 				<mean>0.05624582460420848</mean>
# 				<std>0.04999397584427608</std>
# 				<dtype>float32</dtype>
# 				<valid_pixels>40969170</valid_pixels>
# 				<total_pixels>69293700</total_pixels>
# 			</item>
# 			<item>
# 				<band_number>4</band_number>
# 				<height_range>above_2m</height_range>
# 				<min>0.0</min>
# 				<max>0.9819592833518982</max>
# 				<mean>0.15735576288218678</mean>
# 				<std>0.1676844449912774</std>
# 				<dtype>float32</dtype>
# 				<valid_pixels>40969170</valid_pixels>
# 				<total_pixels>69293700</total_pixels>
# 			</item>
# 			<item>
# 				<band_number>5</band_number>
# 				<height_range>below_3m</height_range>
# 				<min>0.0</min>
# 				<max>0.9012020230293274</max>
# 				<mean>0.12658524690639328</mean>
# 				<std>0.11216709134143049</std>
# 				<dtype>float32</dtype>
# 				<valid_pixels>40969170</valid_pixels>
# 				<total_pixels>69293700</total_pixels>
# 			</item>
# 			<item>
# 				<band_number>6</band_number>
# 				<height_range>below_10m</height_range>
# 				<min>0.0</min>
# 				<max>0.9700438976287842</max>
# 				<mean>0.19413473594900751</mean>
# 				<std>0.17573478644671306</std>
# 				<dtype>float32</dtype>
# 				<valid_pixels>40969170</valid_pixels>
# 				<total_pixels>69293700</total_pixels>
# 			</item>
# 			<item>
# 				<band_number>7</band_number>
# 				<height_range>10-30m</height_range>
# 				<min>0.0</min>
# 				<max>0.9586530327796936</max>
# 				<mean>0.05994743730468545</mean>
# 				<std>0.11100636871313647</std>
# 				<dtype>float32</dtype>
# 				<valid_pixels>40969170</valid_pixels>
# 				<total_pixels>69293700</total_pixels>
# 			</item>
# 			<item>
# 				<band_number>8</band_number>
# 				<height_range>above_30m</height_range>
# 				<min>0.0</min>
# 				<max>0.062060337513685226</max>
# 				<mean>0.0002735795036929599</mean>
# 				<std>0.0015873906791766825</std>
# 				<dtype>float32</dtype>
# 				<valid_pixels>40969170</valid_pixels>
# 				<total_pixels>69293700</total_pixels>
# 			</item>
# 		</bands>
# 		<units>cover</units>
# 		<tiled>true</tiled>
# 		<block_size>
# 			<item>256</item>
# 			<item>256</item>
# 		</block_size>
# 		<compression>zstd</compression>
# 	</geospatial_metadata>
# 	<als_metadata>
# 		<train_area>7498.509053999999</train_area>
# 		<test_area>1265.7581250000007</test_area>
# 		<captures>
# 			<item>
# 				<date>30/01/2020</date>
# 				<area>2536</area>
# 				<sensor>RIEGL Q680i-S</sensor>
# 			</item>
# 			<item>
# 				<date>07/02/2020</date>
# 				<area>2048</area>
# 				<sensor>RIEGL Q680i-S</sensor>
# 			</item>
# 			<item>
# 				<date>23/02/2020</date>
# 				<area>599</area>
# 				<sensor>RIEGL Q680i-S</sensor>
# 			</item>
# 			<item>
# 				<date>13/04/2020</date>
# 				<area>1985</area>
# 				<sensor>RIEGL Q680i-S</sensor>
# 			</item>
# 			<item>
# 				<date>14/04/2020</date>
# 				<area>3782</area>
# 				<sensor>RIEGL Q680i-S</sensor>
# 			</item>
# 			<item>
# 				<date>10/09/2020</date>
# 				<area>166</area>
# 				<sensor>RIEGL Q680i-S</sensor>
# 			</item>
# 			<item>
# 				<date>12/09/2020</date>
# 				<area>2822</area>
# 				<sensor>RIEGL Q680i-S</sensor>
# 			</item>
# 		</captures>
# 	</als_metadata>
# 	<imagery_metadata>
# 		<mosaic_tiles>
# 			<item>JL1KF01A_0031_20201226_1325274_MSS_Ortho</item>
# 			<item>JL1KF01A_0032_20201226_1325275_MSS_Ortho</item>
# 			<item>JL1KF01A_0032_20201226_200036508_MSS_Ortho</item>
# 			<item>JL1KF01A_0031_20201226_1325656_MSS_Ortho_2</item>
# 			<item>JL1KF01A_0007_20220109_1325278_MSS_Ortho</item>
# 			<item>JL1GF02A_0005_20201220_1325480_MSS_Ortho_1</item>
# 			<item>JL1KF01A_0030_20201226_1325656_MSS_Ortho</item>
# 			<item>JL1KF01A_0031_20201226_1325656_MSS_Ortho_3</item>
# 			<item>JL1GF02A_0005_20201220_1325480_MSS_Ortho</item>
# 			<item>JL1KF01A_0032_20201226_1325274_MSS_Ortho</item>
# 			<item>JL1KF01A_0033_20201226_1325656_MSS_Ortho</item>
# 			<item>JL1GF02B_0011_20201108_1325560_MSS_Ortho</item>
# 			<item>JL1KF01A_0031_20201226_1325656_MSS_Ortho</item>
# 			<item>JL1KF01A_0031_20201226_1325656_MSS_Ortho_1</item>
# 			<item>JL1GF02B_0009_20201108_1325560_MSS_Ortho</item>
# 			<item>JL1KF01A_0030_20201226_1325280_MSS_Ortho</item>
# 			<item>JL1KF01A_0032_20201226_1325656_MSS_Ortho</item>
# 			<item>JL1KF01A_0033_20201226_1325274_MSS_Ortho</item>
# 		</mosaic_tiles>
# 	</imagery_metadata>
# </MetaData>
